# %%
## Level-2 Task-1

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Import data
data=pd.read_csv(r"C:\Users\sneha\Downloads\Dataset (1).csv")
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
# Create a histogram to visualize the distribution of aggregate ratings
plt.figure(figsize=(8, 6))
plt.hist(data['Aggregate rating'], bins=10, edgecolor='k')
plt.xlabel('Aggregate Rating')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Aggregate Ratings')
plt.show()

# Determine the most common rating range
most_common_rating_range = data['Aggregate rating'].mode()

print("Most Common Rating Range:", most_common_rating_range.values[0])
# Out:
# Most Common Rating Range: 0.0

# %%
# Calculate the average number of votes received by restaurants
avg_votes = data['Votes'].mean()
print("Average Number of Votes Received by Restaurants:", round(avg_votes, 2))
# Out:
# Average Number of Votes Received by Restaurants: 156.91

# %%
##Level 2 task 1 completed

# %%
## Level-2 Task-2

# %%
## Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Import data
data1 = pd.read_csv(r"C:\Users\sneha\Downloads\Dataset (1).csv")
data1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
# Drop rows with missing or empty 'Cuisines' values
data1.dropna(subset=['Cuisines'], inplace=True)

# Split the 'Cuisines' column to get individual cuisines
cuisine_combinations = data1['Cuisines'].str.split(', ')

# Flatten the list of cuisine combinations
all_cuisines = [cuisine for sublist in cuisine_combinations for cuisine in sublist]

# Calculate the most common cuisine combinations
common_cuisine_combinations = pd.Series(all_cuisines).value_counts()

# Display the most common combinations
print("Most Common Combinations of Cuisines:")
print(common_cuisine_combinations.head(10))
# Out:
# Most Common Combinations of Cuisines:
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Mughlai          995
# Italian          764
# Bakery           745
# Continental      736
# Cafe             703
# Desserts         653
# South Indian     636
# Name: count, dtype: int64

# %%
# Calculate the average rating for each cuisine combination
average_ratings = data1.groupby('Cuisines')['Aggregate rating'].mean()

# Sort the combinations by average rating in descending order
sorted_combinations = average_ratings.sort_values(ascending=False)

# Display the top-rated cuisine combinations
print("Top-Rated Cuisine Combinations:")
print(sorted_combinations.head(10))
# Out:
# Top-Rated Cuisine Combinations:
# Cuisines
# Burger, Bar Food, Steak            4.9
# American, Burger, Grill            4.9
# American, Caribbean, Seafood       4.9
# American, Coffee and Tea           4.9
# Mexican, American, Healthy Food    4.9
# Italian, Bakery, Continental       4.9
# BBQ, Breakfast, Southern           4.9
# European, German                   4.9
# Hawaiian, Seafood                  4.9
# Sunda, Indonesian                  4.9
# Name: Aggregate rating, dtype: float64

# %%
##Level-2 Task -2 completed

# %%
##Level-2 Task -3

# %%
## Import data
data1 = pd.read_csv(r"C:\Users\sneha\Downloads\Dataset (1).csv")
data1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from sklearn.cluster import DBSCAN

# %%
# Create a map centered at a specific location (e.g., city center)
m = folium.Map(location=[72.829976, 19.12663], zoom_start=2) 

# Create a marker cluster group
marker_cluster = MarkerCluster().add_to(m)

# Add markers for restaurant locations to the cluster group
for index, row in data1.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Restaurant Name'],
    ).add_to(marker_cluster)

# Display the map
m.save('restaurant_map.html')

# %%
## Level-2 Task-3 completed

# %%
# Extract latitude and longitude coordinates
X = data1[['Latitude', 'Longitude']]

# Apply DBSCAN clustering
eps = 0.1  # Adjust the epsilon value based on your data
min_samples = 5  # Adjust the minimum number of samples based on your data
db = DBSCAN(eps=eps, min_samples=min_samples).fit(X)

# Add cluster labels to the DataFrame
data1['Cluster'] = db.labels_

# Create a map centered at a specific location (e.g., city center)
m = folium.Map(location=[72.829976, 19.12663], zoom_start=2)  # Replace with actual coordinates

# Create a marker cluster group
marker_cluster = MarkerCluster().add_to(m)

# Add markers for restaurant locations with cluster labels
for index, row in data1.iterrows():
    if row['Cluster'] != -1:  # Exclude unclustered data points (-1 label)
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=f"Restaurant: {row['Restaurant Name']}, Cluster: {row['Cluster']}",
        ).add_to(marker_cluster)

# Display the map
m.save('clustered_restaurant_map.html')  # Save the map as an HTML file

# %%
##Level-2 Task-4

# %%
# Group restaurants by name and count the number of locations
chain_counts = data1['Restaurant Name'].value_counts()

# Filter chains by specifying a minimum number of locations
min_chain_locations = 2  # Adjust as needed
restaurant_chains = chain_counts[chain_counts >= min_chain_locations].index.tolist()

# Print the list of restaurant chains
print("Restaurant Chains:")
print(restaurant_chains)
# Out:
# Restaurant Chains:
# ['Cafe Coffee Day', "Domino's Pizza", 'Subway', 'Green Chick Chop', "McDonald's", 'Keventers', 'Pizza Hut', 'Giani', 'Baskin Robbins', 'Barbeque Nation', "Giani's", 'Barista', "Dunkin' Donuts", 'Costa Coffee', 'Pind Balluchi', 'Pizza Hut Delivery', 'Twenty Four Seven', 'Wah Ji Wah', 'Sagar Ratna', 'Starbucks', 'KFC', 'Chaayos', 'Republic of Chicken', "Haldiram's", 'Burger King', 'Shree Rathnam', 'Bikanervala', 'Moti Mahal Delux', 'Frontier', 'Aggarwal Sweets', 'Bikaner Sweets', "Karim's", 'Behrouz Biryani', 'Chicago Pizza', '34, Chowringhee Lane', 'Apni Rasoi', 'Madras Cafe', 'Wow! Momo', 'Burger Point', 'Gopala', "Nirula's Ice Cream", 'Shama Chicken Corner', 'Yo! China', 'Sardar A Pure Meat Shop', "Berco's", 'Cocoberry', 'Punjabi Chaap Corner', 'Chowringhee', 'Kebab Xpress', 'Ovenstory Pizza', 'Faasos', 'Punjabi Tadka', 'Angels in my Kitchen', "Chawla's�_", 'China Town', 'Mocha', 'Tpot', "Tibb's Frankie", 'Dolce Gelato', 'Slice of Italy', 'BTW', 'Khan Chacha', 'The Yellow Chilli', 'Nazeer Foods', 'RollsKing', 'Chinese Hut', 'Moti Mahal Delux Tandoori Trail', 'Bikaner Sweets & Restaurant', 'The Diet Kitchen', 'Pudding & Pie', 'Wrapss', 'Sanjha Chulha', 'Mainland China', 'Al Bake', 'Kings Kulfi', 'Southy', 'Biryani Blues', 'Cafe Coffee Day - The Lounge', 'The Beer Cafe', 'Mr. Sub', 'Punjabi Rasoi', 'Goli Vada Pav No. 1', 'Farzi Cafe', "TGI Friday's", 'Aggarwal Sweet Corner', 'Red Chilli', 'Shree Bikaner Misthan Bhandar', 'Mad Over Donuts', 'The Midnight Heroes', 'Sandoz', 'The Chinese Hut', 'SGF - Spice Grill Flame', "Chili's", 'Punjab Grill', "Nando's", 'Kettle & Kegs', 'Cake Point', 'Viva Hyderabad', 'Instapizza', 'Pita Pit', 'Da Pizza Corner', "Flirty Momo's", "Nathu's Sweets", 'Aggarwal Sweet India', 'Happy Hakka', 'Nukkadwala', 'Texas Roadhouse', 'Swagath', 'Kake Da Hotel', 'Chinese Corner', "L'Opera", 'Captain Grub', 'Mx Corn', 'Momo-Cha', "AB's - Absolute Barbecues", "Nirula's", 'Public Cafe', 'Bawarchi', 'Burger Xpress', 'Super Cake Shop', "Kwality Wall's Swirl's", 'South Indian Hut', 'Sugar & Spice - Le Marche', 'Punjabi Zaika', 'Deez Biryani & Kebabs', 'Bun Intended', 'Nite Bites', 'Gola Sizzlers', 'Hong Kong Express', "Applebee's", "Colonel's Kababz", 'FreshMenu', 'GoGourmet', 'Pakwan', 'Chai Point', "Chawla's 2", "Qureshi's Kabab Corner", 'Jungle Jamboree', 'The Kathis', 'Chaska', 'Tea Villa Cafe', 'Kathi Junction', 'Zaika', 'Hot Pot', "Nizam's Kathi Kabab", 'Puri Bakers', "DCK- Dana Choga's Kitchen", 'Open Oven', 'Big Chill', 'Meatwale.com', "Punjabi's Veg Grill", 'Rainbows', 'The Coffee Bean & Tea Leaf', 'Chai Garam', 'Aapki Rasoi', 'Pirates of Grill', 'Gelato Vinto', "Jamie's Italian", 'Tikka Junction', 'Mitra Da Dhaba', 'Kerala Cafe', 'Aggarwal Sweets India', "Chawla's Tandoori Junction", 'Roll Club', 'Chaophraya', 'Aggarwal Sweet Centre', 'Cakes & Bakes', 'Talaga Sampireun', 'Just Vada Pav', 'Wok On Fire', 'Defence Bakery', 'Indian Coffee House', 'Taco Bell', 'Cafe Turtle', 'Desi Vibes', 'Palmshore', 'The Chaiwalas', 'Punjab Restaurant', "Chawla's Chic Inn", 'Shahenshah', 'Shawarma Wala', "QD's Restaurant", 'Chinese Food Corner', 'Wah G Wah', 'Bats On Delivery', 'Health Buzzz', 'Sri Balaji', 'Midnight Hunger Hub', 'HuHot Mongolian Grill', 'Baked Buns', "Kanwarji's", 'Sushiya Express', 'Polka Pastry & Snack Bar', 'Saravana Bhavan', 'Hira Sweets', 'Food Scouts', 'Gazebo', 'Bunty Dhaba', 'Foodhall', 'Havmor Ice Cream', 'Aggarwal Bikaner Sweets', 'Naivedyam', 'Tikka Town', 'Movenpick', 'Urban Punjab', 'D�_ner Grill', 'Pizza Station', 'Joost Juice Bar', 'New Madras Cafe', 'The Chai Story', 'Hasty Tasty', 'Pizza Hub', 'Habibi Express', 'Goosebumps', 'Amul Ice-Cream Parlour', 'Foodies', 'True Blue', 'Big Yellow Door', 'Punjabi Dhaba', 'Muradabadi Shahi Biryani & Chicken Corner', 'Changezi Chicken', 'Bharat Sweets', 'Jaiveer Naan & Chaap', 'Little Chef', 'BarShala', 'Speedy Chow', 'Rollmaal', 'Dilli Darbar', 'Niti Shake & Ice Cream Hub', 'The Golden Dragon', 'Tea Halt', 'Burger Singh', 'Bikkgane Biryani', 'Zizo', 'Chin ...

# %%
#Top 10 restaurant chains who has highest number of chains 

# Filter for restaurants that appear more than once (potential chains)
restaurant_chains = chain_counts[chain_counts > 1]

if not restaurant_chains.empty:
    print("Restaurant Chains Identified:")
    print(restaurant_chains.head(10))
else:
    print("No Restaurant Chains Identified in the Dataset.")
# Out:
# Restaurant Chains Identified:
# Restaurant Name
# Cafe Coffee Day     83
# Domino's Pizza      79
# Subway              63
# Green Chick Chop    51
# McDonald's          48
# Keventers           34
# Pizza Hut           30
# Giani               29
# Baskin Robbins      28
# Barbeque Nation     26
# Name: count, dtype: int64

# %%
# Filter the DataFrame to include only rows for restaurant chains
chain_data1 = data1[data1['Restaurant Name'].isin(restaurant_chains)]

# Calculate average ratings for each chain
chain_ratings = chain_data1.groupby('Restaurant Name')['Aggregate rating'].mean()

# Calculate the total number of votes received by each chain
chain_votes = chain_data1.groupby('Restaurant Name')['Votes'].sum()

# Combine the ratings and votes into a single DataFrame
chain_stats = pd.DataFrame({'Average Rating': chain_ratings, 'Total Votes': chain_votes})

# Sort the chains by average rating or total votes, as needed
chain_stats = chain_stats.sort_values(by='Average Rating', ascending=False)
# chain_stats = chain_stats.sort_values(by='Total Votes', ascending=False)

# Print the statistics for restaurant chains
print("Restaurant Chain Ratings and Popularity:")
print(chain_stats)
# Out:
# Restaurant Chain Ratings and Popularity:
# Empty DataFrame
# Columns: [Average Rating, Total Votes]
# Index: []

# %%
##Level-2 Task-4 completed
